# %%
pip install spacy
#SpaCy is an open-source natural language processing (NLP) library designed  for tasks such as tokenization, part-of-speech tagging, named entity recognition, dependency parsing, and more.
# Out:
# ...
#   Obtaining dependency information for spacy from https://files.pythonhosted.org/packages/90/f0/0133b684e18932c7bf4075d94819746cee2c0329f2569db526b0fa1df1df/spacy-3.7.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for spacy-loggers<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/33/78/d1a1a026ef3af911159398c939b1509d5c36fe524c7b644f34a5146c4e16/spacy_loggers-1.0.5-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for murmurhash<1.1.0,>=0.28.0 from https://files.pythonhosted.org/packages/71/46/af01a20ec368bd9cb49a1d2df15e3eca113bbf6952cc1f2a47f1c6801a7f/murmurhash-1.0.10-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for cymem<2.1.0,>=2.0.2 from https://files.pythonhosted.org/packages/c1/c3/dd044e6f62a3d317c461f6f0c153c6573ed13025752d779e514000c15dd2/cymem-2.0.8-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
import spacy

# %%
# en_core_web_lg-Large English model. This model has an extensive vocabulary and high-quality word vectors.
# !python -m spacy download en_core_web_lg
# Out:
# ...
#      ---------------------------------------- 0.0/587.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/587.7 MB ? eta -:--:--
#      -------------------------------------- 0.0/587.7 MB 262.6 kB/s eta 0:37:19
#      -------------------------------------- 0.1/587.7 MB 409.6 kB/s eta 0:23:55
#      -------------------------------------- 0.1/587.7 MB 654.9 kB/s eta 0:14:58
#      ---------------------------------------- 0.3/587.7 MB 1.4 MB/s eta 0:07:14
#      ---------------------------------------- 0.7/587.7 MB 2.5 MB/s eta 0:03:52
#      ---------------------------------------- 1.3/587.7 MB 3.8 MB/s eta 0:02:34
#      ---------------------------------------- 1.8/587.7 MB 4.6 MB/s eta 0:02:07
#      ---------------------------------------- 2.3/587.7 MB 5.5 MB/s eta 0:01:47
#      ---------------------------------------- 2.7/587.7 MB 5.9 MB/s eta 0:01:39
#      ---------------------------------------- 3.2/587.7 MB 6.2 MB/s eta 0:01:34
# ...

# %%
#loading large english vocabulary into nlp object
nlp = spacy.load("en_core_web_lg")
nlp

# %%
#tokenization of text
doc = nlp("Donad Trump was President of USA")

# %%
doc
# Out:
# Donad Trump was President of USA

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
#checks entities 
doc.ents
# Out:
# (Donad Trump, USA)

# %%
#displacy library is used to display name and entity
from spacy import displacy
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donad Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was President of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div></span>

# %%
#reading json file and storing into data variable 
import json
with open('payment_terms_.json', 'rb') as f:
    data = json.load(f)

# %%
data
# Out:
# {'examples': [{'id': 783,
#    'text': "(c)mrbwill pay undisputed amounts within 30 days after receiving Supplier's invoice.",
#    'meta': {},
#    'annotation_approver': None,
#    'labels': [[41, 48, 'Payment Term']]},
#   {'id': 784,
#    'text': 'MSA Tech Services (9/06}CONFIDENTIAL INFORMATION Supplier must not invoice mrb more than 90 calendar days after Supplier is permitted to issue an invoiceunderthis Agreement(“Late Invoices”)orinitially raise a claim for paymentof a previously issued invoice morethan 6 monthsafter the invoice date (“Late Claims’).',
#    'meta': {},
#    'annotation_approver': None,
#    'labels': []},
#   {'id': 785,
#    'text': 'Supplier will immediately, but in no event more than 10business days after discovery of an over-billing, reimburse mrbfor any over-billing disclosed by the audit andsimple interest for the period oftime between the date the overpayment was made and the date that mrb wasreimbursedat a rate of 1% per month.',
#    'meta': {},
# ...

# %%
data['examples'][0]
# Out:
# {'id': 783,
#  'text': "(c)mrbwill pay undisputed amounts within 30 days after receiving Supplier's invoice.",
#  'meta': {},
#  'annotation_approver': None,
#  'labels': [[41, 48, 'Payment Term']]}

# %%
data['examples'][0].keys()
# Out:
# dict_keys(['id', 'text', 'meta', 'annotation_approver', 'labels'])

# %%
data['examples'][0]['text']
# Out:
# "(c)mrbwill pay undisputed amounts within 30 days after receiving Supplier's invoice."

# %%
data['examples'][67]['labels']
# Out:
# [[72, 92, 'Payment Term'], [188, 203, 'Payment Term']]

# %%
data['examples'][67]['meta']
# Out:
# {}

# %%
#extracting text and labels from entire data ,storing it into temp_dict and appending dictionary into list
training_data = []
for example in data['examples']:
  temp_dict = {}
  temp_dict['text'] = example['text']
  temp_dict['entities'] = []
  temp_dict['entities'] = example['labels']
  training_data.append(temp_dict)
  
print(training_data[0])
# Out:
# {'text': "(c)mrbwill pay undisputed amounts within 30 days after receiving Supplier's invoice.", 'entities': [[41, 48, 'Payment Term']]}

# %%
training_data[0]['text']
# Out:
# "(c)mrbwill pay undisputed amounts within 30 days after receiving Supplier's invoice."

# %%
training_data[67]['entities']
# Out:
# [[72, 92, 'Payment Term'], [188, 203, 'Payment Term']]

# %%
training_data[0]['text'][41:48]
# Out:
# '30 days'

# %%
training_data[67]['text'][188:203]
# Out:
# 'sixty (60) days'

# %%
#function return zero if lis1 is empty 
def Enquiry(lis1):
    if len(lis1) == 0:
        return 0
    else:
        return 1

# %%
#by applying enquiry function new list is created where entities are not null
train_valid_data =[]
for i in range(len(training_data)):
    if Enquiry(training_data[i]['entities']):
        train_valid_data.append(training_data[i])

# %%
from spacy.tokens import DocBin
from tqdm import tqdm

nlp = spacy.blank("en") # load a new spacy model
doc_bin = DocBin()

# %%
#extracting present entities and storing it into docbin repo
from spacy.util import filter_spans

for training_example  in tqdm(train_valid_data): 
    text = training_example['text']
    labels = training_example['entities']
    doc = nlp.make_doc(text) 
    ents = []
    for start, end, label in labels:
        span = doc.char_span(start, end, label=label, alignment_mode="contract".)
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    filtered_ents = filter_spans(ents)
    doc.ents = filtered_ents 
    doc_bin.add(doc)

doc_bin.to_disk("train.spacy")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 1278.19it/s]

# %%
# https://spacy.io/usage/training#quickstart                     copy configuration from this website

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# [+] Auto-filled config with all values
# [+] Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
#if instance is already running it kills instance and restart again
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# !python -m spacy train config.cfg --output ./ --paths.train ./train.spacy --paths.dev ./train.spacy
# Out:
# [i] Saving to output directory: .
# [i] Using CPU
#
# =========================== Initializing pipeline ===========================
# [+] Initialized pipeline
#
# ============================= Training pipeline =============================
# [i] Pipeline: ['tok2vec', 'ner']
# [i] Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     31.50    0.00    0.00    0.00    0.00
#  16     200         37.96    694.47  100.00  100.00  100.00    1.00
#  37     400          4.88     22.27  100.00  100.00  100.00    1.00
#  63     600          0.00      0.00  100.00  100.00  100.00    1.00
#  95     800          0.00      0.00  100.00  100.00  100.00    1.00
# 135    1000          0.00      0.00  100.00  100.00  100.00    1.00
# 184    1200          0.00      0.00  100.00  100.00  100.00    1.00
# ...

# %%
#loading best model
nlp_ner = spacy.load("model-best")

# %%
doc = nlp_ner("i will deposit payment within 9 days ")

colors = {"PAYMENT TERM": "#F67DE3"}
options = {"colors": colors} 

spacy.displacy.render(doc, style="ent", options= options, jupyter=True)

# %%
doc = nlp_ner("(c)mrbwill pay undisputed amounts within 30 days after receiving Supplier's invoice.")

colors = {"PAYMENT TERM": "#F67DE3"}
options = {"colors": colors} 

spacy.displacy.render(doc, style="ent", options= options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">(c)mrbwill pay undisputed amounts within
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Payment Term</span>
# </mark>
#  after receiving Supplier's invoice.</div></span>

# %%
doc = nlp_ner("i have given you 30 thousand rupees, i am expecting it back with 10 weeks ")

colors = {"PAYMENT TERM": "#F67DE3"}
options = {"colors": colors} 

spacy.displacy.render(doc, style="ent", options= options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">i have given you
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Payment Term</span>
# </mark>
#  rupees, i am expecting it back with
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Payment Term</span>
# </mark>
#  </div></span>
